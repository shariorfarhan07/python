# %%
a=[1,2,3,4,5,6,7,8,9]
b=[10,20,30,40,0,60,70,80,90]
c=[11,21,31,41,51,61,71,811,119]
d=[11,22,33,44,55,66,77,88,99]
e=[15,25,35,45,55,65,75,85,95]

def maxnumber123(x):
  max=x[0]
  for i in x:
    if max<i:
      max=i
  print(max)
maxnumber123(e)
maxnumber123(d)
maxnumber123(c)
maxnumber123(b)
maxnumber123(a)
# Out:
# 95
# 99
# 811
# 90
# 9

# %%
def sabrina():
  print("sabrina")
  print("1")
  print("sabrina")
  print()
  
sabrina()
sabrina()
sabrina()
# Out:
# sabrina
# 1
# sabrina
#
# sabrina
# 1
# sabrina
#
# sabrina
# 1
# sabrina

# %%
print("sabrina")
print("1")
print("sabrina")
print()

print("sabrina")
print("1")
print("sabrina")
print()
# Out:
# sabrina
# 1
# sabrina
#
# sabrina
# 1
# sabrina

# %%
def brac():
  print("i hate bracU")
brac()
brac()
brac()
brac()
brac()
# Out:
# i hate bracU
# i hate bracU
# i hate bracU
# i hate bracU
# i hate bracU

# %%
def brac(a):# here a is a paramitter 
  print("i hate bracU "*a)
brac(5)
# Out:
# i hate bracU i hate bracU i hate bracU i hate bracU i hate bracU

# %%
def student(name,id,dep):
  print("My name is",name,'My id is',id,"and my dept.",dep)

student("sabrina","6735468","cse")
student("korim","6735469","cse")
student("rohim","6735470","cse")
# Out:
# My name is sabrina My id is 6735468 and my dept. cse
# My name is korim My id is 6735469 and my dept. cse
# My name is rohim My id is 6735470 and my dept. cse

# %%
def brac(a):
  return "i hate bracU "*a



print(brac(5))
# Out:
# i hate bracU i hate bracU i hate bracU i hate bracU i hate bracU
