# %%
import numpy as np

# %%
a=np.array([1,2,3])
print(a)
# Out:
# [1 2 3]

# %%
b=np.array([[7.0,8.0,9.0,9.0,4.5],[5.9,8.6,5.4,8.7,4.5]],dtype="int32")
print(b)
# Out:
# [[7 8 9 9 4]
#  [5 8 5 8 4]]

# %%
#get dimension
a.ndim
# Out:
# 1

# %%
#get dimension
b.ndim
# Out:
# 2

# %%
b.shape# tells shape
# Out:
# (2, 5)

# %%
a.shape
# Out:
# (3,)

# %%
a.dtype
# Out:
# dtype('int64')

# %%
b.dtype
# Out:
# dtype('int32')

# %%
a.itemsize
# Out:
# 8

# %%
b.itemsize
# Out:
# 4

# %%
a.size #byte
# Out:
# 3

# %%
a=np.array([[1,2,3,4,5],[1,5,9,8,7]])

# %%
a[1,2]
# Out:
# 9

# %%
#get a specific row
a[0,:]
# Out:
# array([1, 2, 3, 4, 5])

# %%
#get a specific row
a[1,:]
# Out:
# array([1, 5, 9, 8, 7])

# %%
#get a specific column
a[:,2]
# Out:
# array([3, 9])
