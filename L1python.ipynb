# %%
farhan=5
print(farhan)
# Out:
# 5

# %%
#$%^&*
_FARHAN
123VAR
VAR123

# %%
A=12345
B=123.5256985268712365
C='THIS IS A STRING'
C="THIS IS A STRING"
TEST="FARHAN'S"
TEST='FARHAN"S'
b=False
b=True
print(TEST)
# Out:
# FARHAN"S

# %%
a=5
print(a)
a=a+6
a=a+9
print(a)
# Out:
# 5
# 20

# %%
a=input()
print(a)
# Out:
# farhan
# farhan

# %%
a=int(input())
b=int(input())
c=a+b
print(c)
# Out:
# 5
# 6
# 11

# %%
print("enter a")
input()
print("enter b")
input()
print("enter c")
input()
# Out:
# enter a
# 5
# enter b
# 6
# enter c
# 2
# '2'

# %%
a=int(input())
if a==5:
  print('if was true')
  if cond:
    print
    print(0)
else:
  print()
# Out:
# 5
# if was true

# %%
A=int(input())
B=int(input())
x=A+B
print("X = ",x)
# Out:
# 5
# 5
# X = 10

# %%
# Out:
# 5
