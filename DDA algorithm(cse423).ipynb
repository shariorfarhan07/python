# %%
x1,y1=2,2
x2,y2=5,7
m=(y1-y2)/(x1-x2)
if -1<m<1:
  steps=abs(x1-x2)
  for i in range(steps):
    print('x',x1,"\ty=",y1,"\t\t round x=",round(x1),"\ty=",round(y1))
    x1=x1+1
    y1=y1+m
else:
  steps=abs(y1-y2)
  for i in range(steps):
    print('x',x1,"\ty=",y1,"\t\t round x=",round(x1),"\ty=",round(y1))
    x1=x1+1
    y1=y1+1/m
# Out:
# x 2 	y= 2 		 round x= 2 	y= 2
# x 3 	y= 2.6 		 round x= 3 	y= 3
# x 4 	y= 3.2 		 round x= 4 	y= 3
# x 5 	y= 3.8000000000000003 		 round x= 5 	y= 4
# x 6 	y= 4.4 		 round x= 6 	y= 4

# %%
x1,y1=2,2
x2,y2=5,7
m=(y1-y2)/(x1-x2)
if -1<m<1:
  steps=abs(x1-x2)
  for i in range(steps):
    print('x {:.1f}\ty={:.1f}\t\t round x={:.1f}\ty={:.1f}'.format(x1, y1, round(x1, 2), round(y1, 2)))
    x1=x1+1
    y1=y1+m
else:
  steps=abs(y1-y2)
  for i in range(steps):
    print('x {:.1f}\ty={:.1f}\t\t round x={:.1f}\ty={:.1f}'.format(x1, y1, round(x1, 2), round(y1, 2)))
    x1=x1+1
    y1=y1+1/m
# Out:
# x 2.0	y=2.0		 round x=2.0	y=2.0
# x 3.0	y=2.6		 round x=3.0	y=2.6
# x 4.0	y=3.2		 round x=4.0	y=3.2
# x 5.0	y=3.8		 round x=5.0	y=3.8
# x 6.0	y=4.4		 round x=6.0	y=4.4

# %%
round(3.236,2)
# Out:
# 3.24
