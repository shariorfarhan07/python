# %%
a=int(input())
b=int(input())
if a==b:
  print("this two numbers are equal")
elif a>b:
  print("the first number is greater")
else:
  print("secound number is greater")
# Out:
# 5
# 10
# secound number is greater

# %%
print(type(10))
print(type(11.111111111111))
print(type("abc"))
type(input())
int()
float()
str()
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# 5
# str

# %%
a="farhan is the best  "+str(3)
a=10
a=10.55
a=[5,6,'farhan',15.5,'breaking bad is the best',[55,5]]
print(a[-2])
print("fa")
# Out:
# breaking bad is the best
# fa
