# %%
def methodName():
  print("farhan")
  print("farhan")

methodName()
methodName()
methodName()
# Out:
# farhan
# farhan
# farhan
# farhan
# farhan
# farhan

# %%
a=[1,5,9,8,75,6,3,1]


b=[1,5,9,8,75,6,3,1]
c=[1,5,9,8,75,6,3,1]
d=[1,5,9,8,75,6,3,1]
e=[1,5,9,8,75,6,3,1]
maxx=a[0]


for i in a:
  if i >maxx:
    maxx=i
print(maxx)
# Out:
# 75

# %%
a=[1,5,9,8,75,6,3,1]


b=[1,5,9,8,75,6,3,1]
c=[1,5,9,100,8,75,6,3,1]
d=[1,5,9,8,75,6,3,1]
e=[1,5,9,8,75,6,3,1]
maxx=a[0]

def method(v): # b is a variable
  maxx=v[0]
  for i in v:
    if i >maxx:
      maxx=i
  print(maxx)

method(a)
method(b)
method(c)
method(d)
method(e)
# Out:
# 75
# 75
# 100
# 75
# 75

# %%
def count(a):
  for i in range(a):
    print(i+1,end="")
  print()



def height(b):
  for i in range(b):
    count(b)


height(5)
# Out:
# 12345
# 12345
# 12345
# 12345
# 12345

# %%
def count(a):
  for i in range(a):
    print(i+1,end="")
  print()



def height(b):
  for i in range(b):
    count(i+1)


height(5)
# Out:
# 1
# 12
# 123
# 1234
# 12345

# %%
#fixed param
def methodName(a,b,c):
  print(a*b*c)

methodName(4,5,6)
methodName(4,5)
# Out:
# 120
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-13abd278ce69> in <module>()
#       4
#       5 methodName(4,5,6)
# ----> 6 methodName(4,5)
#
# TypeError: methodName() missing 1 required positional argument: 'c'

# %%
def methodName(a=1,b=1,c=1):
  print(a)
  print(b)
  print(c)
  print(a*b*c)
  print("end")

methodName(5)
methodName(5,6)
methodName(5,6,5)
methodName("farhan",6,5)
# Out:
# 5
# 1
# 1
# 5
# end
# 5
# 6
# 1
# 30
# end
# 5
# 6
# 5
# 150
# end
# farhan
# 6
# 5
# farhanfarhanfarhanfarhanfarhanfarhanfarhanfarhanfarhanfarhanfarhanfarhanfarhanfarhanfarhanfarhanfarhanfarhanfarhanfarhanfarhanfarhanfarhanfarhanfarhanfarhanfarhanfarhanfarhanfarhan
# end

# %%
def height(b):
  print(b)

height('farhan;')
b=f
# Out:
# farhan;

# %%
def method(*a):
  print(type(a))
  print(a)
  for i in a:
    print(i)

method(1,1,2,3,'farhan',4,5,6,7,8,9)
# Out:
# <class 'tuple'>
# (1, 1, 2, 3, 'farhan', 4, 5, 6, 7, 8, 9)
# 1
# 1
# 2
# 3
# farhan
# 4
# 5
# 6
# 7
# 8
# 9

# %%
def method(**a):
  print(a)

method(farhan=50,b=5,g=15)
# Out:
# {'farhan': 50, 'b': 5, 'g': 15}

# %%
def method(*b,**a):
  print(b)
  print(a)
method(farhan=50,b=5,g=15)
method(1,2,3,5,4,8,"farhan")
method(1,2,3,5,4,8,"farhan",farhan=50,b=5,g=15)
# Out:
# ()
# {'farhan': 50, 'b': 5, 'g': 15}
# (1, 2, 3, 5, 4, 8, 'farhan')
# {}
# (1, 2, 3, 5, 4, 8, 'farhan')
# {'farhan': 50, 'b': 5, 'g': 15}

# %%
def count(a):
  for i in range(a):
    print(i+1,end="")
  print()

def space(g):
  for i in range(g):
    print(" ",end="")
  

def height(b):
  for i in range(b):
    space(b-i-1)
    count(i+1)


height(5)
# Out:
#     1
#    12
#   123
#  1234
# 12345

# %%
def count(a):
  for i in range(a):
    print(i+1,end="")
  

def space(g):
  for i in range(g):
    print(" ",end="")
  

def height(b):
  for i in range(b):
    space(b-i-1)
    count(i+1)
    count(i+1)
    print()
    


height(5)
# Out:
#     11
#    1212
#   123123
#  12341234
# 1234512345
