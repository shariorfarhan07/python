# %%
y='sabrina'
print(y)
# Out:
# sabrina

# %%
print(len(y))
# Out:
# 7

# %%
print(ord(y[5])+1)
a=ord(y[5])+1
print(chr(a))
# Out:
# 111
# o

# %%
a="A"
print(ord(a))
print(chr(65))
# Out:
# 65
# A

# %%
y="sabrina rahman"
print(ord(y[4]+1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-f1d6cf9ffae6> in <module>()
#       1 y="sabrina rahman"
# ----> 2 print(ord(y[4]+1))
#
# TypeError: must be str, not int

# %%
a="s"


print(a)
# Out:
# s

# %%
y=input("enter a string")
print(y[0:3])
a=len(y)
print(a)
print(y[a-4:a])
# Out:
# enter a stringdepsjgv seof hd
# dep
# 15
# f hd

# %%
a="sabrina"
for i in a:
  print(a)
# Out:
# sabrina
# sabrina
# sabrina
# sabrina
# sabrina
# sabrina
# sabrina

# %%
i=0
a="sabrina rahman"
while i<len(a):
  print(a[i]) #a[staring index:end+1] i=0 a[0:0]
  i+=1
# Out:
# s
# a
# b
# r
# i
# n
# a
#
# r
# a
# h
# m
# a
# n

# %%
y="sabrina"
print(y[4]+1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-6d53c8bd1417> in <module>()
#       1 y="sabrina"
# ----> 2 print(y[4]+1)
#
# TypeError: must be str, not int

# %%
a="sabrina rahman"
for i in range len(a):
  print(a[i])
# Out:
#   File "<ipython-input-2-3695dcddf88d>", line 2
#     for i in range len(a):
#                      ^
# SyntaxError: invalid syntax

# %%
temp1="sunny"
temp2="sabrina"
print(temp1+temp2)
# Out:
# sunnysabrina

# %%
#a[staring index:end+1] i=0 a[0:0]
# abc ABC +aAbBcC
#abcde 123 +a1b2c3de
