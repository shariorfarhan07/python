# %%
s="f"

if s=="f":
  print("false")
elif s=="a":
  print("true")
else:
  print("sabrina")
if s=="f":
  print("2nd")
# Out:
# false
# 2nd

# %%
a=[1,55,6,9,502]
s=max(a)
print(s)
# Out:
# 502

# %%
def mmax(a,b):
  if a>b:
    return a
  return b
y=mmax(1100,100)
print(y)
# Out:
# 1100

# %%
a=[50,1,55,6,9,502]
max=a[0] #1
index=0 
i=0
while i <len(a):
  if max<a[i]:
    max=a[i]
    index=i
  i+=1
 
print(max)
print(index)
# Out:
# 55
# 2

# %%
a=[50,1,55,6,9,502]
