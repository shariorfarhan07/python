# %% [markdown]
# 1.write a python program that takes a integer and adds the corresponding cherecter's  ascii value and prints the summation
#
# ---
#
#
# **sample input**:
# ABCD
#
# ---
#
#
# **output**:
# 266

# %%
y="ABCD"
sum=0
b=""
for i in (y):
  b=ord(i)
  sum=sum+b
   
print(sum )
# Out:
# 266

# %% [markdown]
# 2.write a python program that takes a string and converts all the chracter to capital letters .

# %%
s="sabrina"
b=""
 
for i in (s):
  if (i>="A" and i<="Z"):
    print(i)
# Out:
# SABRINA
# S
# A
# B
# R
# I
# N
# A

# %% [markdown]
# 3.write a python program that takes a string and converts all the chracter to small letters .

# %%
s=" SABRINA"
b=""
for i in (s):
  if (i>="a" and i<="z"):
    b=chr(ord(i)-32)
    print(b)

# %% [markdown]
# 4.write a python program that takes a string and prints it in reverse order
#
# example, <br>
# sample input:<br>
# abcd<br>
# output:<br>
# dcba<br>

# %%
s="abcd"
b=""
for i in (s):
  b=i+b
print(b)
# Out:
# dcba

# %%
s=140
h=secound//3600
secoundeft=secound%3600
min=secoundeft//3600
sec=secoundleft%3600
print(h ,":"min ,":", sec)
# Out:
#   File "<ipython-input-9-ccddb38c0876>", line 6
#     print(h ,":"min ,":", sec)
#                   ^
# SyntaxError: invalid syntax
