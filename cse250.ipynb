# %%
r=2
V=24
print('V_1=2*V_4')
print('node1')
print('V_3-V_2=',V)
print('node2 componet')
print('V_2*(1/{price}+1/{price})-V_1/{price}+V_3*(1/{price})-V_4/{price}-2=0'.format(price = r))
print('node2')
print('V_4*(1/{price}+1/{price})-V_3/{price}-4=0'.format(price = r))
# Out:
# V_1=2*V_4
# node1
# V_3-V_2= 24
# node2 componet
# V_2*(1/2+1/2)-V_1/2+V_3*(1/2)-V_4/2-2=0
# node2
# V_4*(1/2+1/2)-V_3/2-4=0

# %%
r=2
V=24
print('V_1=2*V_4')

print('V_3-V_2=',V)

print('V_2*(1/{price}+1/{price})-V_1/{price}+V_3*(1/{price})-V_4/{price}-2=0'.format(price = r))

print('V_4*(1/{price}+1/{price})-V_3/{price}-4=0'.format(price = r))
print('var')
print('V_1\nV_2\nV_3\nV_4')
# Out:
# V_1=2*V_4
# V_3-V_2= 24
# V_2*(1/2+1/2)-V_1/2+V_3*(1/2)-V_4/2-2=0
# V_4*(1/2+1/2)-V_3/2-4=0
# var
# V_1
# V_2
# V_3
# V_4
