# %%
def midpoint_line(x0, y0, x1, y1):
    dx = x1 - x0
    dy = y1 - y0
    d = 2 * dy - dx
    incrE = 2 * dy
    incrNE = 2 * (dy - dx)
    x = x0
    y = y0

    while x < x1:
        rx, ry = convert_from_zone0(x, y, 3)
        print(x, y, d, rx, ry)
        if d <= 0:
            # Choose E
            d = d + incrE
            x = x + 1
        else:
            # Choose NE
            d = d + incrNE
            x = x + 1
            y = y + 1



def midpoint_circle(radius, value):
    d = 1 - radius
    x = 0
    y = radius
    
    while x < y:
        rx, ry = convert_from_zone0(x, y, 3)
        print(x, y, d, rx, ry)
        if d < 0:
            # Choose E
            d = d + 2 * x + 3
            x = x + 1
        else:
            # Choose SE
            d = d + 2 * x - 2 * y + 5
            x = x + 1
            y = y - 1

# %%
(1+8+3+0+1+2+6+6)%8
# Out:
# 3

# %%
a=input()
n=0
for i in a:
  n+=int(i)
n%8
# Out:
# 18301266
# 3
