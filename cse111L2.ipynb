# %%
a='{} this is {} la = {}   '.format("farhan",'sharior','lalalalala!')
print(a)
# Out:
# farhan this is sharior la = lalalalala!

# %%
print ("Hi ! My name is {} and I am {} years old".format("sabrina", 19))
# Out:
# Hi ! My name is sabrina and I am 19 years old

# %%
print ("This is {} {} {} {}".format("one", "two", "three", "four"))
# Out:
# This is one two three four

# %%
print ("This is {3} {2} {1} {0}".format("one", "two", "three", "four"))
# Out:
# This is four three two one

# %%
s = "I am {0}, {1}. I have only {2:.2f}$.".format("sorry", "Alice",50.95876)
print(s)
# Out:
# I am sorry, Alice. I have only 50.96$.

# %%
print("{0:<d}|{1:^20.3f}|{2:>9d}".format(20,20.1235,30))
# Out:
# 20|       20.123       |       30

# %%
print("{:50d}".format(1234))
# Out:
#                                               1234

# %%
print('it\'s me')
print("it's me")
# Out:
# it's me
# it's me

# %%
print("1\t222222\t3")
print("15555\t2\t3555")
print("1\t222222\t3")
print("1555\t222\t3")
# Out:
# 1	222222	3
# 15555	2	3555
# 1	222222	3
# 1555	222	3

# %%
a=[]
print(a)
a.append(500)
print(a)
a.append(150)
a.append(50)
a.append(40)
a.append(160)
a.append(5000)
print(a)
b=a.pop()
print(a)
a.pop()
print(b)
print(a)
b=a.pop(1)
print(b)
print(a)
# Out:
# []
# [500]
# [500, 150, 50, 40, 160, 5000]
# [500, 150, 50, 40, 160]
# 5000
# [500, 150, 50, 40]
# 150
# [500, 50, 40]

# %%
class contact:
  name='null'
  address='null'
  email='null'
  phone='null'
  
  def details(self):
    print('name',self.name)
    print('address',self.address)
    print('email',self.email)
    print('phone',self.phone)
  
if __name__== "__main__":
  c1=contact()#c1 variable contact() constructor
  c2=contact()#c2=contact() object create 
  c3=contact()
  c4=contact()
  c1.name="farhan"
  c1.address='shantinogor'
  c1.email="sh557ariorfarhan"
  c1.phone='01749577'
  c2.name="sabrina"
  c2.address='bonani'
  c2.email="sab@gmail.com"
  c2.phone='0174945626'
  c3.name="rohim"
  c3.address='mohakhali'
  c3.email="rohomi@gmail.com"
  c3.phone='659519'
  print('---------')
  c1.details()
  print('--------*****-')
  c2.details()
  print('---------')
  c3.details()
  print('---------')
  c4.details()
  print('---------')
# Out:
# ---------
# name farhan
# address shantinogor
# email sh557ariorfarhan
# phone 01749577
# --------*****-
# name sabrina
# address bonani
# email sab@gmail.com
# phone 0174945626
# ---------
# name rohim
# address mohakhali
# email rohomi@gmail.com
# phone 659519
# ---------
# name null
# address null
# email null
# phone null
# ---------

# %%
name='farhan'

# %%
class contact:
  name='null'
  address='null'
  email='null'
  phone='null'
  
  def details(self):
    print('name',self.name)
    print('address',self.address)
    print('email',self.email)
    print('phone',self.phone)
    
  def getName(self):
    return self.name  #get method returns a value of variable 
  def setName(self,a):
    self.name=a


c1=contact()
c1.setName('bhaia')
print(c1.getName())
# Out:
# bhaia
