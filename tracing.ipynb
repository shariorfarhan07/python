# %%
x = 0
y =0
sum = 0
while (x <=10):
  y = x - 3
  print(x)
  y = 40
  while (y > 22):
    if ((sum > 30) and (sum < 40)):
      sum = sum + x * 2 
    elif ((sum > 40) and (sum < 50)): 
      sum = sum + x * 3
    else:
      sum = sum + 23
    print(sum)
    y = y - 10
  x += 2
# Out:
# 0
# 23
# 46
# 2
# 52
# 75
# 4
# 98
# 121
# 6
# 144
# 167
# 8
# 190
# 213
# 10
# 236
# 259

# %%
x = 0
y =0
sum = 0
while (x < 10):
  y = x - 3
  x+=1
  print(y)
# Out:
# -3
# -2
# -1
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
test =""
i  = 0
j = 0
k = 15

while (i< 5):
  
  test = "-->"
  k=k-1
  j = k
  print(j)
  while (j > 10 ):
    test = str(i) + str(j) + test + str(i) + str(j)
    print(test)
    j-=1
  i+=1
# Out:
# 14
# 014-->014
# 013014-->014013
# 012013014-->014013012
# 011012013014-->014013012011
# 13
# 113-->113
# 112113-->113112
# 111112113-->113112111
# 12
# 212-->212
# 211212-->212211
# 11
# 311-->311
# 10

# %%
j=15
i=0
x=str(i+ j)
print(x)
# Out:
# 15

# %%
x = 0
y =0
sum = 0
while (x < 10):
  y = x - 3
  x+=1
  
  while (y < 3):
    sum = (sum % 2) + x - y * 2 
    print(sum)
     
    if (x > 5):
      x+=1
    else:
      x += 2
    y=y+1
# Out:
# 7
# 8
# 7
# 8
# 6
# 5

# %%
#tracing part 2 
test = ""
i = 0
j = 0
k = 15
test = "-->"
while (i< 5):
  k=k-1
  j =k
  while (j > 10 ):
    test = str(i) + str(j) + "-->" + test
    print(test)
    j=j-1
    
  i+=1
# Out:
# 014-->-->
# 013-->014-->-->
# 012-->013-->014-->-->
# 011-->012-->013-->014-->-->
# 113-->011-->012-->013-->014-->-->
# 112-->113-->011-->012-->013-->014-->-->
# 111-->112-->113-->011-->012-->013-->014-->-->
# 212-->111-->112-->113-->011-->012-->013-->014-->-->
# 211-->212-->111-->112-->113-->011-->012-->013-->014-->-->
# 311-->211-->212-->111-->112-->113-->011-->012-->013-->014-->-->

# %%
x = 0
p =0
sum = 0
p = 1
x = 2
sum = 0
while (p < 10):               #task  6
  q =x+(p-(sum+5//3)//3.0%2) 
  x+=1
  sum = sum + (x) + q
  print(sum)
  if (x > 5):
    p += 4//2
  else:
    p += 3%1
  sum = sum + p
print(sum)
# Out:
# 6.0
# 15.0
# 25.0
# 37.0
# 55.0
# 80.0
# 110.0
# 147.0
# 158.0

# %%
test = 1
j = 0 
k = 100
while (k > 0):  
  while (j < k ):
    test = k - j + 21
    print(1 + test)
    j=10+j
  k-=10
# Out:
# 122
# 112
# 102
# 92
# 82
# 72
# 62
# 52
# 42
# 32

# %%
test = 1
j = 0
k = 100
while (k > 0):
  while (j < k ):
    test = k - j + 11
    print(str((1 + test // 3)) +"12")
    j+=10;
    
  k-=10;
# Out:
# 3812
# 3412
# 3112
# 2812
# 2412
# 2112
# 1812
# 1412
# 1112
# 812

# %%
x = 0
y = 0
sum = 0
while(x <18):
  y = x // 2
  while(y < x):
    p = (x + 15.0) /2
    sum = (sum + 3) + x + y * 3 + int(p)
    print(sum)
    y = y + 3
 
  x = x + 3
# Out:
# 18
# 46
# 82
# 127
# 173
# 228
# 282
# 345
# 417

# %%
x = 0
y = 0
sum = "0"
while (x < 9):
  y = x / 2
  while (y < x):
    p = (x + 5.0) / 2
    sum = (sum + str(2) + str(x)) + "y * 2" + str(int(p)) 
    print(sum)
    y = y + 1
    
  x = x + 2
  if (x > 5):
    sum = "2"
  else:
    sum += "3"
# Out:
# 0322y * 23
# 0322y * 23324y * 24
# 0322y * 23324y * 2424y * 24
# 226y * 25
# 226y * 2526y * 25
# 226y * 2526y * 2526y * 25
# 228y * 26
# 228y * 2628y * 26
# 228y * 2628y * 2628y * 26
# 228y * 2628y * 2628y * 2628y * 26

# %%
test = ""
i = 1
j = 1
k = 14
test = "-->"
while (i< 5):  
  j = --k
  while (j > 9 ) :
    test = str(i + (j-2) )+ "-->" + test
    print(test)
    j-=1
    
  i+=1
# Out:
# 13-->-->
# 12-->13-->-->
# 11-->12-->13-->-->
# 10-->11-->12-->13-->-->
# 9-->10-->11-->12-->13-->-->
# 14-->9-->10-->11-->12-->13-->-->
# 13-->14-->9-->10-->11-->12-->13-->-->
# 12-->13-->14-->9-->10-->11-->12-->13-->-->
# 11-->12-->13-->14-->9-->10-->11-->12-->13-->-->
# 10-->11-->12-->13-->14-->9-->10-->11-->12-->13-->-->
# 15-->10-->11-->12-->13-->14-->9-->10-->11-->12-->13-->-->
# 14-->15-->10-->11-->12-->13-->14-->9-->10-->11-->12-->13-->-->
# 13-->14-->15-->10-->11-->12-->13-->14-->9-->10-->11-->12-->13-->-->
# 12-->13-->14-->15-->10-->11-->12-->13-->14-->9-->10-->11-->12-->13-->-->
# 11-->12-->13-->14-->15-->10-->11-->12-->13-->14-->9-->10-->11-->12-->13-->-->
# 16-->11-->12-->13-->14-->15-->10-->11-->12-->13-->14-->9-->10-->11-->12-->13-->-->
# 15-->16-->11-->12-->13-->14-->15-->10-->11-->12-->13-->14-->9-->10-->11-->12-->13-->-->
# 14-->15-->16-->11-->12-->13-->14-->15-->10-->11-->12-->13-->14-->9-->10-->11-->12-->13-->-->
# ...

# %%
p = 5
q = 6
r = 9
sum = 0
if (p < 12) :
      print(r + 2)
else :
  print(r + p)

if (q > 20):
  print(r + 19);
elif (q <= 6) :
  print(q + 3);
else:
  print(p + q + r)     
if (r > 15) :
  print(r)
elif (r == 0) :
  print(p + q)
else :
  print(p);
if (sum != 0) :
  print(3)
else:
  print(sum + 32)    
if p > 0 and r < 10:
  print(p + r)
else :
  print(p - r)
# Out:
# 11
# 9
# 5
# 32
# 14

# %%
p=[True,True,False,True,True,True]
c=0
q=len(p)
while c<15:
  if p[c%q] and p[(c+1)%q] :
    p[(c+1)%q]=False
  else:
    p[(c+1)%q]=p[c%q] and p[(c+1)%q]
    if p[c%q] or True:
      p[(c+15)%q]=True
    

  c+=1
  print(p)
# Out:
# [True, False, False, True, True, True]
# [True, False, False, True, True, True]
# [True, False, False, False, True, True]
# [True, False, False, False, False, True]
# [True, True, False, False, False, False]
# [False, True, True, False, False, False]
# [False, False, True, True, False, False]
# [False, False, False, True, True, False]
# [False, False, False, False, True, True]
# [True, False, False, False, False, True]
# [True, True, False, False, False, False]
# [False, True, True, False, False, False]
# [False, False, True, True, False, False]
# [False, False, False, True, True, False]
# [False, False, False, False, True, True]

# %%
15%2
# Out:
# 1
