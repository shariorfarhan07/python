# %%
a=(["sabrina","Brac university","briani"],["anamika","east west university",'pizza'],['fahim','brac university','tea'])
for i in a:
  print(i)
# Out:
# ['sabrina', 'Brac university', 'briani']
# ['anamika', 'east west university', 'pizza']
# ['fahim', 'brac university', 'tea']

# %%
for i in a:
  print(i[0],"studies in","'"+i[1]+"'","like\"s",i[2])
# Out:
# sabrina studies in 'Brac university' likes briani
# anamika studies in 'east west university' likes pizza
# fahim studies in 'brac university' likes tea

# %%
aa="sabrina"
b='rahman'
c=aa+" "+b
print(c)
# Out:
# sabrina rahman

# %%
for i in a:
  print(i)
  for j in i:
    print(j)

# %%
w=[1,2,3,4,5,6,7,8,9,1,5,65,95,65,35,15,5,66,92,45,95,72,15,92,948,565,468,6456,45,46]
print(w[0:5])
print(w[5:13])
print(w)
#5 

#4
#6
#7
#5-> 7->5
# Out:
# [1, 2, 3, 4, 5]
# [6, 7, 8, 9, 1, 5, 65, 95]
# 2

# %%
name="farhan"
uni="brac"
food="biriani"
print(name+" studies in "+uni+" likes "+food)
# Out:
# farhan studies in brac likes biriani

# %%
a={"farhan":"01749555777","sabrina":"0175555555555",'rahim':"56896214"}
print(a["farhan"])
# Out:
# 01749555777
