# %%
class circle:
  r=0
  def radius(self):  #get method 
    return self.r

  def radiusBoshao(self,a): #set method 
    self.r=a
  def sab():
    print(o)

a=circle()
print(a.radius())
a.radiusBoshao(5)
print(a.radius())
# Out:
# 0
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-0ba8ceea0f01> in <module>()
#      14 a.radiusBoshao(5)
#      15 print(a.radius())
# ---> 16 a.sub()
#
# AttributeError: 'circle' object has no attribute 'sub'

# %%
s='sabrina'
class circle:
  r=0
  def radius(self):  #get method 
    return self.r

  def radiusBoshao(self,a): #set method 
    self.r=a
  def sub(self):
    print(s)

a=circle()
b=circle()
c=circle()

print(a.radius())
a.radiusBoshao(5)
print(a.radius())
a.sub()


print('for b')
b.r=50
print(b.radius())
b.radiusBoshao(5)
print(b.radius())
b.sub()


print('for a')
b.r=550
print(a.radius())
a.radiusBoshao(5)
print(a.radius())
a.sub()
# Out:
# 0
# 5
# sabrina
# for b
# 50
# 5
# sabrina
# for a
# 5
# 5
# sabrina

# %%
class cake:
  flav='bread'
  def __init__(self,a):
    self.flav=a


a=cake("chocolate")
print(a.flav)
b=cake("vanilla")
print(b.flav)
c=cake("strawberry")
print(c.flav)
d=cake("blackforest")
print(d.flav)
e=cake('ice cream')
print(e.flav)
# Out:
# chocolate
# vanilla
# strawberry
# blackforest
# ice cream

# %%
class cake:
  flav='bread'
  def __init__(self,a):
    self.flav=a+' cake'


a=cake("chocolate")
print(a.flav)
b=cake("vanilla")
print(b.flav)
c=cake("strawberry")
print(c.flav)
d=cake("blackforest")
print(d.flav)
e=cake('ice cream')
print(e.flav)
# Out:
# chocolate cake
# vanilla cake
# strawberry cake
# blackforest cake
# ice cream cake
