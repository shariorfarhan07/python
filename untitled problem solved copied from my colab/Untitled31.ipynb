# %%
class Marks:
  def __init__(self,a):
    self.mark=a
  def __add__(self, *other):
    for i in other:
      self.mark+=int(i.mark)
    return Marks(self.mark)



Q1 = Marks(int(5))
Q2 = Marks(int(4))
Lab = Marks(int(3))
Mid = Marks(int(2))
Final = Marks(int(1))
total = Q1 + Q2 + Lab + Mid + Final
print("Total marks: {}".format(total.mark))
# Out:
# Total marks: 15

# %%
class Teacher:
  def __init__(self,a,b):
    self.instructor=a
    self.dep=b
    self.course=[]

  def addCourse(self,c):
    self.course.append(c.name)

  def printDetail(self):
    print("============================================================")
    print("Name: "+self.instructor+" \nDepartment: "+self.dep+"\nList of courses")
    print("============================================================")
    for i in self.course:
      print(i)
    print("============================================================")

class Course:
  def __init__(self,a):
    self.name=a
 

t1 = Teacher("Saad Abdullah", "CSE")
t2 = Teacher("Mumit Khan", "CSE")
t3 = Teacher("Sadia Kazi", "CSE")
c1 = Course("CSE 110 Programming Language I")
c2 = Course("CSE 111 Programming Language-II")
c3 = Course("CSE 220 Data Structures")
c4 = Course("CSE 221 Algorithms")
c5 = Course("CCSE 230 Discrete Mathematics")
c6 = Course("CSE 310 Object OrientedProgramming")
c7 = Course("CSE 320 Data Communications")
c8 = Course("CSE 340 Computer Architecture")
t1.addCourse(c1)
t1.addCourse(c2)
t2.addCourse(c3)
t2.addCourse(c4)
t2.addCourse(c5)
t3.addCourse(c6)
t3.addCourse(c7)
t3.addCourse(c8)
t1.printDetail()
t2.printDetail()
t3.printDetail()
# Out:
# ...
# Name: Saad Abdullah
# Department: Saad Abdullah
# List of courses
# ...
# CSE 110 Programming Language I
# CSE 111 Programming Language-II
# ...
# Name: Mumit Khan
# Department: Mumit Khan
# List of courses
# ...
# CSE 220 Data Structures
# CSE 221 Algorithms
# CCSE 230 Discrete Mathematics
# ...
# Name: Sadia Kazi
# Department: Sadia Kazi
# List of courses
# ...
# CSE 310 Object OrientedProgramming
# CSE 320 Data Communications
# CSE 340 Computer Architecture
# ...

# %%
class Team:
  def __init__(self,s=''):
    self.name=s
    self.player=[]
  def setname(self,a):
    self.name=a
  def addPlayer(self,b):
    self.player.append(b.name)
  def setName(self,b):
    self.name=b
  def printDetail(self):
    print("============================================================")
    print("Team:",self.name)
    print("List of Players:")
    print( self.player)
    print("============================================================")




class Player:
  def __init__(self,a):
    self.name=a
   


b = Team()
b.setName('Bangladesh')
mashrafi = Player("Mashrafi")
b.addPlayer(mashrafi)
tamim = Player("Tamim")
b.addPlayer(tamim)
b.printDetail()
a = Team("Australia")
ponting = Player("Ponting")
a.addPlayer(ponting)
lee = Player("Lee")
a.addPlayer(lee)
a.printDetail()
# Out:
# ...
# Team: Bangladesh
# List of Players:
# ['Mashrafi', 'Tamim']
# ...
# Team: Australia
# List of Players:
# ['Ponting', 'Lee']
# ...

# %%
class Color:
  def __init__(self,a):

C1 = Color(input("First Color: ").lower())
C2 = Color(input("Second Color: ").lower())
C3 = C1 + C2
print("Color formed:", C3.clr)
