# %%
numberOfTimes=30
count=1
while count<=numberOfTimes:
  print("count=",count, "% 5==", count%5,end="  ")
  if count%3==0:
    print("Sabrina")
  elif count%2==0:
    print("Sunny")
  else:
    print("Rony")
  count=count+1
# Out:
# count= 1 % 5== 1  Rony
# count= 2 % 5== 2  Sunny
# count= 3 % 5== 3  Sabrina
# count= 4 % 5== 4  Sunny
# count= 5 % 5== 0  Rony
# count= 6 % 5== 1  Sabrina
# count= 7 % 5== 2  Rony
# count= 8 % 5== 3  Sunny
# count= 9 % 5== 4  Sabrina
# count= 10 % 5== 0  Sunny
# count= 11 % 5== 1  Rony
# count= 12 % 5== 2  Sabrina
# count= 13 % 5== 3  Rony
# count= 14 % 5== 4  Sunny
# count= 15 % 5== 0  Sabrina
# count= 16 % 5== 1  Sunny
# count= 17 % 5== 2  Rony
# count= 18 % 5== 3  Sabrina
# count= 19 % 5== 4  Rony
# count= 20 % 5== 0  Sunny
# count= 21 % 5== 1  Sabrina
# count= 22 % 5== 2  Sunny
# count= 23 % 5== 3  Rony
# count= 24 % 5== 4  Sabrina
# count= 25 % 5== 0  Rony
# count= 26 % 5== 1  Sunny
# count= 27 % 5== 2  Sabrina
# count= 28 % 5== 3  Sunny
# count= 29 % 5== 4  Rony
# count= 30 % 5== 0  Sabrina
