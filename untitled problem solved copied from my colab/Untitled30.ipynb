# %%
class data:
  def __init__(self, x):
    self.x = x

  def __add__(self, other):
    
    return self.x / other.x
num1 = data(10)
num2 = data(20)

str1 = data('cse')

str2 = data('111')

print(num1 + num2)
# Out:
# 0.5

# %%
class A:
  def __init__(self,x):
    self.x=x
  def __str__(self):
    return "sabrina"
  
a=A(5)
print(a)
# Out:
# sabrina
