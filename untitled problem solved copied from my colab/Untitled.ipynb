# %% [markdown]
# #Method	Description
# #clear()-->	Removes all the elements from the dictionary
# #copy()-->	Returns a copy of the dictionary
# #fromkeys()-->	Returns a dictionary with the specified keys and value
# #get()-->	Returns the value of the specified key
# #items()-->	Returns a list containing a tuple for each key value pair
# #keys()-->	Returns a list containing the dictionary's keys
# #pop()-->	Removes the element with the specified key
# #popitem()-->	Removes the last inserted key-value pair
# #setdefault()-->	Returns the value of the specified key. If the key does not exist: insert the key, with the specified value
# #update()-->	Updates the dictionary with the specified key-value pairs
#
#
# ```

# %%
d={'key1':'value1','key2':'value2','key3':'value3','key4':'value4',}
print(d['key2'])
print(d['key3'])
print(d['key1'])
print(d)
# Out:
# value2
# value3
# value1
# {'key1': 'value1', 'key2': 'value2', 'key3': 'value3', 'key4': 'value4'}

# %%
w=[1,2,3,4,5,6]
print(w)
w=[]
print(w)
# Out:
# [1, 2, 3, 4, 5, 6]
# []

# %%
d={}
d['farhan']='01749555777'
print(d)
d['farhan']='0174xxxxxxx'
d['korim']='017495564577'
d['rahim']='01744567'
d['fahim']='017454677'
d['asif']='0174954567'
print(d)
print(d['korim'])
print(d['asif'])
# Out:
# {'farhan': '01749555777'}
# {'farhan': '0174xxxxxxx', 'korim': '017495564577', 'rahim': '01744567', 'fahim': '017454677', 'asif': '0174954567'}
# 017495564577
# 0174954567

# %%
d={}
d[1]=1111
d[2]=1112
d[3]='farhan'
d[4]=1114
print(d)
# Out:
# {1: 1111, 2: 1112, 3: 'farhan', 4: 1114}

# %%
d={'key1':'value1','key2':'value2','key3':'value3','key4':'value4',}
for i in d:
  print(i)
# Out:
# key1
# key2
# key3
# key4

# %%
d={'key1':'value1','key2':'value2','key3':'value3','key4':'value4',}
for i in d:
  print(d[i])
# Out:
# value1
# value2
# value3
# value4

# %%
d={'key1':'value1','key2':'value2','key3':'value3','key4':'value4',}
for i,j in d.items():
  print(i,j)
# Out:
# key1 value1
# key2 value2
# key3 value3
# key4 value4

# %%
d={'key1':'value1','key2':'value2','key3':'value3','key4':'value4',}
for i in d.keys():
  print(i)
# Out:
# key1
# key2
# key3
# key4

# %%
d={'key1':'value1','key2':'value2','key3':'value3','key4':'value4',}
for i in d.values():
  print(i)
# Out:
# value1
# value2
# value3
# value4

# %%
d={'key1':'value1','key2':'value2','key3':[12,12,36,45,8,5],'key4':'value4',}
for i in d.keys():
  print(i)
# Out:
# key1
# key2
# key3
# key4

# %%
d={'key1':'value1','key2':'value2','key3':[12,12,36,45,8,5],'key4':'value4',}
for i in d.values():
  print(i)
# Out:
# value1
# value2
# [12, 12, 36, 45, 8, 5]
# value4

# %% [markdown]
# tuple

# %%
s=(1,2,3,4,5,6)
print(s)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
s=(1,'farhan',3,4,5,6)
s[0]=111
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-3d29dc2b619a> in <module>()
#       1 s=(1,'farhan',3,4,5,6)
# ----> 2 s[0]=111
#       3 print(s)
#
# TypeError: 'tuple' object does not support item assignment

# %%
s=1,2,3,4,5,6,7,8,9,'farhan'
print(s)
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8, 9, 'farhan')

# %%
s='sharior','hossain','farhan'
print(s)
i,j,k=s
print(i)
print(j)
print(k)
# Out:
# ('sharior', 'hossain', 'farhan')
# sharior
# hossain
# farhan

# %%
s=0
while True:
  n=input()
  if n=="stop":
    break
  s+=float(n)
print(s)
# Out:
# 1
# 2
# 3
# 4
# 5
# stop
# 15.0

# %%
s=[]
while True:
  n=input()
  if n=="stop":
    break
  s.append(int(n))
c=0
sum=0
while c<len(s):
  sum=sum+s[c]
  c+=1
print(sum)

# %%
s=1,2,3,4,5,6,7,8,9,'farhan'
print(s.count(5))
# Out:
# 1

# %%
f='farhan'
print(f)
fl=list(f)
print(fl)
w={}
for i in fl:
  if i in w.keys():
    w[i]=w[i]+1
  else:
    w[i]=1

print(w)
# Out:
# farhan
# ['f', 'a', 'r', 'h', 'a', 'n']
# {'f': 1, 'a': 2, 'r': 1, 'h': 1, 'n': 1}

# %%
f='farhan'
print(f)
fl=list(f)
print(fl)
w={}
i=0

while i<len(fl):
  if fl[i] in w.keys():
    w[fl[i]]=w[fl[i]]+1
  else:
    w[fl[i]]=1
  i+=1
print(w)
# Out:
# farhan
# ['f', 'a', 'r', 'h', 'a', 'n']
# {'f': 1, 'a': 2, 'r': 1, 'h': 1, 'n': 1}

# %%
l=[1,2,3,4,5,6]
print(5 in l )
# Out:
# True

# %%
a=set()
b=set()
a.add(1)
a.add(2)
a.add(1)
a.add(3)
a.add(4)
print(a)
b.add(1)
b.add('farhan')
b.add(111)
b.add(31)
b.add(41)
c=set([1,2,41,3,5])

print(b)
print(b.difference(a).difference(c))
print(b)
# Out:
# {1, 2, 3, 4}
# {1, 41, 111, 'farhan', 31}
# {111, 'farhan', 31}
# {1, 41, 111, 'farhan', 31}
