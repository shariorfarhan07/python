# %%
a=("fffff",1,56.5,"afdasd565")
b=('a','b','c')
d=("farhan","a")*3
c=a+b

print((b*5)[5:10] )
print(d)
print(b)
# Out:
# ('c', 'a', 'b', 'c', 'a')
# ('farhan', 'a', 'farhan', 'a', 'farhan', 'a')
# ('a', 'b', 'c')

# %%
s="farhan"
print(s)
b=tuple(s)
print(b)
g=[1,2,3,4,5,6,5]
c=tuple(g)
print(c)
d=list(s)
print(d)
# Out:
# farhan
# ('f', 'a', 'r', 'h', 'a', 'n')
# (1, 2, 3, 4, 5, 6, 5)
# ['f', 'a', 'r', 'h', 'a', 'n']

# %%
g=[1,2,3,4,5,6,5]
sum=0
for i in g:
  sum+=i
print(sum)
# Out:
# 26

# %%
a=[   ["rony",6]   ,    ["sunny",6.0]   ,    ['sabrina',5.4], ['uncle',6.4]  ] 
sum=0
for i in a:
  sum+=i[1] 
print(sum)
print(sum/len(a))
print(len(a))
# Out:
# 23.799999999999997
# 5.949999999999999
# 4

# %%
a=[   ["rony",6]   ,    ["sunny",6.0]   ,    ['sabrina',5.4], ['uncle',6.4]  ] 
sum=0
for  i in a:

  sum=sum+i [1]
  print(sum)
# Out:
# 6
# 12.0
# 17.4
# 23.799999999999997

# %%
s='x'

if s=='a':
  print("found a")

elif s=='b':
  print("found b 159")
else:
  print("not found")



if s=='b':
  print("found b")
elif s=='b':
  print("found b")
elif s=='b':
  print("found b")
else:
  print("gidfheryser")
print("my task is done")
# Out:
# not found
# gidfheryser
# my task is done
