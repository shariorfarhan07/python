# %%
a=123
type(a)
# Out:
# int

# %%
a="123"
type(a)
# Out:
# str

# %%
a=125.6
type(a)
# Out:
# float

# %%
a=1234567894554564351241648645315
print(a)
type(a)
# Out:
# 1234567894554564351241648645315
# int

# %%
a=input()
type(a)
# Out:
# 15
# str

# %%
a=input("enter something\n")
type(a)
# Out:
# enter something
# 1455
# str

# %%
a=input("enter something\n")
a=int(a)
print(a)
type(a)
# Out:
# enter something
# 4565
# 4565
# int

# %%
a=input("enter something\n")
a=float(a)
print(a)
type(a)
# Out:
# enter something
# 52
# 52.0
# float

# %%
#for i in range(start,end+1,increment):

for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
a=['farhan','junayed','sabrina','is','tibrina',2.0]
for i in a:
  print(i)
  i=0
print(a)
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# ['farhan', 'junayed', 'sabrina', 'is', 'tibrina', 2.0]
