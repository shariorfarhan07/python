# %%
a=[7,30,6,5,8,9,50,500]
i=0
j=0
max=0
while i < len(a):
  while j <len(a):
    if a[max]<a[j]:
      temp=a[i]
      a[i]=a[j]
      a[j]=temp
    j+=1
  i+=1
print(a)
# Out:
# [500, 7, 6, 5, 8, 9, 30, 50]
