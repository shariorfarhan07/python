# %%
class Student:
  department = 'CSE' # Class Variable
  number=0
  def __init__(self,name, id):
    self.name = name # Instance Variable
    self.__id = id
    Student.number+=1
 

a = Student('ABC', 17101)
print(Student.number)
b = Student('DEF', 18202)
print(Student.number)
b1 = Student('DEF', 18202)
b2 = Student('DEF', 18202)
b3 = Student('DEF', 18202)
b4 = Student('DEF', 18202)
b5 = Student('DEF', 18202)
b6 = Student('DEF', 18202)
print(Student.number)


print(a.name)
print(b.department)
print(Student.department)
Student.department='sabrina\'s cake bake classes'
print(a.name)
print(b.name)
# Out:
# 1
# 2
# 8
# ABC
# CSE
# CSE
# ABC
# DEF
