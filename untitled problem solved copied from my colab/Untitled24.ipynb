# %%
try:
  s=int(input())
  print(s)
except:
  print("invalid input")
# Out:
# 159
# 159

# %%
while True:
  try:
    s=int(input())
    break
  except:
    print("please enter an int")
print(s)
# Out:
# fr
# please enter an int
# 15.
# please enter an int
# 15
# 15

# %%
s=input()
try:
  s=int(s)
  print("it is an int")
except:
  try:
    s=float(s)
    print("it is a float")
  except:
    print("it is a string")
# Out:
# f 152
# it is a string

# %%
try:
  s=0/0
except ValueError:
  print(ValueError )
except ZeroDivisionError:
  print("u cant divide zero with zero")
# Out:
# u cant divide zero with zero
